# %%
# 商品購入時の消費税を出す関数を作成(110円に消費税10％を加えた金額を出す関数)
# 変数price = 商品の金額110
# 変数tax = 消費税% 10
def total_price(price:int,tax:int) -> int :
  total = price * (1 + (tax / 100))
  print(f"{total}円")


total_price(110,10)
# Out:
# 121.00000000000001円
